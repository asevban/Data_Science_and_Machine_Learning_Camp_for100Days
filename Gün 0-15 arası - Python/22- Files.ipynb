# %%
# %%writefile myfile.txt
# test 1
# test 2
# test 3
# Out:
# Writing myfile.txt

# %%
myFile = open("myfile.txt")

# %%
type(myFile)
# Out:
# _io.TextIOWrapper

# %%
myFile.read()
# Out:
# 'test 1\ntest 2\ntest 3\n'

# %%
myFile.read()
# Out:
# ''

# %%
myFile.seek(0)  # satırı başa alır
# Out:
# 0

# %%
myFile.read()
# Out:
# 'test 1\ntest 2\ntest 3\n'

# %%
myFile.close()

# %%
with open("myfile.txt") as myFile:
    myContent = myFile.read()

# %%
myContent
# Out:
# 'test 1\ntest 2\ntest 3\n'

# %%
with open("myfile.txt", mode="w") as myNewFile:   # "w" write anlamına gelir 
        myNewFile.write("test 4")

# %%
myNewFile
# Out:
# <_io.TextIOWrapper name='myfile.txt' mode='w' encoding='cp1254'>

# %%
with open("myfile.txt",mode="r") as myFile2:
    myContent = myFile2.read()

# %%
myContent
# Out:
# 'test 4'
