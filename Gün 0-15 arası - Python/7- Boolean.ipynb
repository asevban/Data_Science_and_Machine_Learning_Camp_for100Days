# %%
True
# Out:
# True

# %%
False
# Out:
# False

# %%
myBooelan = True

# %%
type(myBooelan)
# Out:
# bool

# %%
5 > 3
# Out:
# True

# %%
yas = input("yas giriniz: ")
# Out:
# yas giriniz:  22

# %%
yas = int(yas)

# %%
yas
# Out:
# 22

# %%
yas>18
# Out:
# True
