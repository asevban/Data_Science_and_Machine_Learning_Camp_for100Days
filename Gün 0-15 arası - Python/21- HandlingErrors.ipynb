# %%
age = input("enter age: ")
# Out:
# enter age:  55

# %%
age
# Out:
# '55'

# %%
int(age)
# Out:
# 55

# %%
# try - expcept

# %%
while True:
    try:
        myAge = int(input("enter age: "))
        print(myAge * 2)
        break
    except ValueError:
        print("enter your age!!!")
    else:
        print("else executed")
    finally:  #her türlü çalışır
        print("finally")
