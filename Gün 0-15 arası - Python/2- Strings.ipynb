# %%
name = "ahmet sevban yıldırım"

# %%
type(name)
# Out:
# str

# %%
name.capitalize()   #nokta sonra tab bas
# ilk kelimenin baş harfi büyük yazar
# Out:
# 'Ahmet sevban yıldırım'

# %%
x = 10

# %%
# eğer tab ile gelen foksiyonları çok anlamıyorsan hatırlamıyorsan help fonk kullan

help(name.count)
# Out:
# Help on built-in function count:
#
# count(...) method of builtins.str instance
#     S.count(sub[, start[, end]]) -> int
#
#     Return the number of non-overlapping occurrences of substring sub in
#     string S[start:end].  Optional arguments start and end are
#     interpreted as in slice notation.

# %%
name.count("a")
# Out:
# 2

# %%
name.count("z")
# Out:
# 0

# %%
name.upper()
# Out:
# 'AHMET SEVBAN YILDIRIM'

# %%
name.lower()
# Out:
# 'ahmet sevban yıldırım'

# %%
help(name.isupper)
# Out:
# Help on built-in function isupper:
#
# isupper() method of builtins.str instance
#     Return True if the string is an uppercase string, False otherwise.
#
#     A string is uppercase if all cased characters in the string are uppercase and
#     there is at least one cased character in the string.

# %%
print(len(name))
# Out:
# 21

# %%
print("ahmet sevban yıldırım")
# Out:
# ahmet sevban yıldırım

# %%
print("ahmet sevban \nyıldırım")
# Out:
# ahmet sevban
# yıldırım

# %%
# \n -> new line

# %%
# escape characters

# %%
# \t -> tab kadar boşluk

# %%
print("ahmet sevban \tyıldırım")
# Out:
# ahmet sevban 	yıldırım

# %% [markdown]
# index

# %%
myString = "hello python"

# %%
myString[0]
# Out:
# 'h'

# %%
myString[1]
# Out:
# 'e'

# %%
myString[5]
# Out:
# ' '

# %%
myString
# Out:
# 'hello python'

# %%
len(myString)
# Out:
# 12

# %%
len(myString) - 1
# Out:
# 11

# %%
name = "brad pit"

# %%
name[len(name) - 1]
# Out:
# 't'

# %%
name[-1]
# Out:
# 't'

# %%
barcode = "ABCD435FB"

# %%
barcode[5]
# Out:
# '3'

# %%
print("A" + "B")
# Out:
# AB

# %%
"A" + "B"
# Out:
# 'AB'

# %%
100 * "a"
# Out:
# 'aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa'

# %%
# slicing, starting index, stopping index, stepping size
# Out:
# '5'

# %%
barcode
# Out:
# 'ABCD435FB'

# %%
# barcode[ starting index : stopping index  : stepping size ]
# Out:
# 'AD5'

# %%
barcode[3::]
# Out:
# 'D435FB'

# %%
barcode[:3:]
# Out:
# 'ABC'

# %%
barcode[::2]
# Out:
# 'AC45B'

# %%
barcode
# Out:
# 'ABCD435FB'

# %%
barcode[3:5:]
# Out:
# 'D4'

# %%
name = "ahmet sevban yıldırım"

# %%
name.index("s")
# Out:
# 6

# %%
name.split()
# Out:
# ['ahmet', 'sevban', 'yıldırım']

# %%
type(name.split())
# Out:
# list
