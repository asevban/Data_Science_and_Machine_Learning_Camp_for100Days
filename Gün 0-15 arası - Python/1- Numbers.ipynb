# %%
print("hello word")
#shift+enter - otomotatik çalıştır.
# Out:
# hello word

# %%
3+5
# Out:
# 8

# %%
5+5
# Out:
# 10

# %%
900/8.5
# Out:
# 105.88235294117646

# %%
4/2
# Out:
# 2.0

# %%
4 / 3
# Out:
# 1.3333333333333333

# %%
 type( 3.3)
# Out:
# float

# %%
2 ** 5
# Out:
# 32

# %%
10 % 3
# Out:
# 1
