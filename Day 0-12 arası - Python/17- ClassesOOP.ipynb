# %%
class Person():
    #property
     #name = ""
    #age = 0
    #gender = ""
    job = ""

    #constructor  method
    def __init__(self,name,age,gender):
        self.name = name
        self.age = age
        self.gender = gender

    #method
    def printName(self):
        print(self.name)

# %%
sevban = Person("sevban" , 22 , "Male")

# %%
sevban.name
# Out:
# 'sevban'

# %%
sevban.age
# Out:
# 22

# %%
sevban.gender
# Out:
# 'Male'

# %%
sevban.job
# Out:
# ''

# %%
sevban.job = "developer"

# %%
sevban.job
# Out:
# 'developer'

# %%
class Dog():
    year = 7
    
    def __init__(self,age=5):
        self.age = age
        self.dogHumanAge = age * self.year
        print("dog oluşturuldu")


    def humanAge(self):
        return self.age * Dog.year   #Dog.year -> self.year

# %%
myDog = Dog(3)
# Out:
# dog oluşturuldu

# %%
myDog.age
# Out:
# 3

# %%
myDog.humanAge()
# Out:
# 21

# %%
myDog.dogHumanAge
# Out:
# 21

# %%
barley = Dog()
# Out:
# dog oluşturuldu

# %%
barley.dogHumanAge
# Out:
# 35
