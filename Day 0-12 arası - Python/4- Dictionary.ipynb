# %%
#key - value pairing

# %%
fruit_list = ["banana" , "apple" ]

# %%
calorie_list = [100,50]

# %%
fitness_dictionary = {"banana":100 , "apple":150}  #anahtar-değer eşleştirmesi

# %%
type(fitness_dictionary)
# Out:
# dict

# %%
fitness_dictionary["banana"]
# Out:
# 100

# %%
fitness_dictionary["apple"]
# Out:
# 150

# %%
fitness_dictionary.keys()
# Out:
# dict_keys(['banana', 'apple'])

# %%
fitness_dictionary.values()
# Out:
# dict_values([100, 150])

# %%
type(fitness_dictionary.values())
# Out:
# dict_values

# %%
list(fitness_dictionary.values()) #liste cevirdik
# Out:
# [100, 150]

# %%
fitness_dictionary["bananas"] = 200

# %%
fitness_dictionary
# Out:
# {'banana': 100, 'apple': 150, 'bananas': 200}

# %%
fitness_dictionary["melon"] = 300

# %%
fitness_dictionary
# Out:
# {'banana': 100, 'apple': 150, 'bananas': 200, 'melon': 300}

# %%
fitness_dictionary.get("apple", 0)
# Out:
# 150

# %%
fitness_dictionary
# Out:
# {'banana': 100, 'apple': 150, 'bananas': 200, 'melon': 300}

# %%
my_mixed_dict = { "ahmet":22 , 1:175 , "burc": "akrep" , "notlar":[90,100,85]}

# %%
my_mixed_dict["notlar"]
# Out:
# [90, 100, 85]

# %%
my_mixed_dict["notlar"][1]
# Out:
# 100

# %%
last_dictionary = {"k1":10,"k2":[10,20,30,40,50],"k3":"string","k4":{"a":100,"b":200}}

# %%
last_dictionary["k4"]["a"]
# Out:
# 100

# %%
last_dictionary["k2"][3]
# Out:
# 40
