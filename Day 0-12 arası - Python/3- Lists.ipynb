# %%
myString =  "hello python"

# %%
myString.split()
# Out:
# ['hello', 'python']

# %%
type(myString.split())
# Out:
# list

# %%
# list

# %% [markdown]
# lists

# %%
myList = [10,20,30]

# %%
type(myList)
# Out:
# list

# %%
print(myList)
# Out:
# [10, 20, 30]

# %%
myList = [10,20,30,40,50,60,70]

# %%
myList[2]
# Out:
# 30

# %%
myList[0] = 100

# %%
myList
# Out:
# [100, 20, 30, 40, 50, 60, 70]

# %%
len(myList)
# Out:
# 7

# %%
myList[-1]
# Out:
# 70

# %%
myList[ len(myList) - 1 ]
# Out:
# 70

# %%
myList[-2]
# Out:
# 60

# %%
myList.append(1)

# %%
myList
# Out:
# [100, 20, 30, 40, 50, 60, 70, 1]

# %%
myList.count(70)
# Out:
# 1

# %%
myList.index(40)
# Out:
# 3

# %%
myList
# Out:
# [100, 20, 30, 40, 50, 60, 70, 1]

# %%
myList.insert(2,35)  # 2. indeks 35 oluacak şekilde güncellenir

# %%
myList
# Out:
# [100, 20, 35, 30, 40, 50, 60, 70, 1]

# %%
myList.pop() #sondakini kaldırır
# Out:
# 1

# %%
myList
# Out:
# [100, 20, 35, 30, 40, 50, 60, 70]

# %%
myList.remove(40)

# %%
myList
# Out:
# [100, 20, 35, 30, 50, 60, 70]

# %%
myList.sort()

# %%
myList
# Out:
# [20, 30, 35, 50, 60, 70, 100]

# %%
x = input("  x:  ")
# Out:
#   x:   1

# %%
print(x)
# Out:
# 10

# %%
y = input(" y: ")
# Out:
#  y:  2

# %%
print(y)
# Out:
# 2

# %% [markdown]
# ### type(x)

# %%
z = input(" z: ")
# Out:
#  z:  3

# %%
print(z)
# Out:
# 3

# %%
inputList = []

# %%
type(inputList)
# Out:
# list

# %%
len(inputList)
# Out:
# 0

# %%
inputList.append(x)
inputList.append(y)
inputList.append(z)

# %%
inputList
# Out:
# ['1', '2', '3']

# %%
inputList[1]
# Out:
# '2'

# %%
inputList[1] * 2
# Out:
# '22'

# %%
type(inputList[1])
# Out:
# str

# %%
myInteger = 50

# %%
str(myInteger)
# Out:
# '50'

# %%
myString = "40"

# %%
int(myString)
# Out:
# 40

# %%
float(myString)
# Out:
# 40.0

# %%
inputList
# Out:
# ['1', '2', '3']

# %%
int(inputList[1]) * 2
# Out:
# 4

# %%
list1 = [1,2,3,4]
list2 = [1,2,3,4]

# %%
list1 + list2
# Out:
# [1, 2, 3, 4, 1, 2, 3, 4]

# %%
list1 * 2
# Out:
# [1, 2, 3, 4, 1, 2, 3, 4]

# %%
mixedList = [ "sevban", 22 , 1.75 ]

# %%
mixedList
# Out:
# ['sevban', 22, 1.75]

# %%
type(mixedList)
# Out:
# list

# %%
type(mixedList[0])
# Out:
# str

# %%
type(mixedList[1])
# Out:
# int

# %%
type(mixedList[2])
# Out:
# float

# %%
myNestedList = [ 10,20, 1.75, "sevban", [1,2,3]]

# %%
myNestedList[0]
# Out:
# 10

# %%
myNestedList[4]
# Out:
# [1, 2, 3]

# %%
myNestedList[4][1]
# Out:
# 2
