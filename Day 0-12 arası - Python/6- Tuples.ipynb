# %%
myList = [10,"a","b",3.14]

# %%
#tuple

# %%
myTuple = (10,"a","b",3.14)

# %%
type(myTuple)
# Out:
# tuple

# %%
myTuple[0]
# Out:
# 10

# %%
#myTuple[0] = 100

# %%
#immutability

# %%
myTuple
# Out:
# (10, 'a', 'b', 3.14)

# %%
myTuple.index("a")
# Out:
# 1

# %%
resultList = list(myTuple)

# %%
resultList
# Out:
# [10, 'a', 'b', 3.14]
